# %%
import pandas as pd

df = pd.read_csv('Minimum Wage Data.csv', encoding='latin')
min_wage = pd.DataFrame()
df.columns
# Out:
# Index(['Year', 'State', 'State.Minimum.Wage',
#        'State.Minimum.Wage.2020.Dollars', 'Federal.Minimum.Wage',
#        'Federal.Minimum.Wage.2020.Dollars', 'Effective.Minimum.Wage',
#        'Effective.Minimum.Wage.2020.Dollars', 'CPI.Average',
#        'Department.Of.Labor.Uncleaned.Data',
#        'Department.Of.Labor.Cleaned.Low.Value',
#        'Department.Of.Labor.Cleaned.Low.Value.2020.Dollars',
#        'Department.Of.Labor.Cleaned.High.Value',
#        'Department.Of.Labor.Cleaned.High.Value.2020.Dollars', 'Footnote'],
#       dtype='object')

# %%
for name,group in df.groupby('State'):
    if min_wage.empty:
        min_wage = group.set_index('Year')[['State.Minimum.Wage']].rename(columns={'State.Minimum.Wage': name})
    else:
        min_wage = min_wage.join(group.set_index('Year')[['State.Minimum.Wage']].rename(columns={'State.Minimum.Wage': name}))
min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0     2.1    0.468   0.15625        1.65       1.0         1.40
# 1969      0.0     2.1    0.468   0.15625        1.65       1.0         1.40
# 1970      0.0     2.1    0.468   1.10000        1.65       1.0         1.60
# 1971      0.0     2.1    0.468   1.10000        1.65       1.0         1.60
# 1972      0.0     2.1    0.468   1.20000        1.65       1.0         1.85
#
#       Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                           ...
# 1968      1.25                  1.25      0.0  ...        0.0    0.0
# 1969      1.25                  1.25      0.0  ...        0.0    0.0
# 1970      1.25                  1.60      0.0  ...        0.0    0.0
# 1971      1.25                  1.60      0.0  ...        0.0    0.0
# 1972      1.60                  1.60      0.0  ...        0.0    1.4
#
# ...

# %%
min_wage['Michigan'].describe()
# Out:
# count    53.000000
# mean      4.540566
# std       2.461884
# min       1.250000
# 25%       3.350000
# 50%       3.350000
# 75%       6.950000
# max       9.650000
# Name: Michigan, dtype: float64
