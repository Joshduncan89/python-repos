# %% [markdown]
# # Sales Analysis

# %% [markdown]
# #### Import necessary libraries

# %%
import os
import pandas as pd

# %% [markdown]
# #### Merge data from each month into one CSV

# %%
path = "./Sales_Data"
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

all_months_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_months_data = pd.concat([all_months_data, current_data])
    
all_months_data.to_csv("all_data_copy.csv", index=False)

# %% [markdown]
# #### Read in updated dataframe

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Clean up the data!
# The first step in this is figuring out what we need to clean. I have found in practice, that you find things you need to clean as you perform operations and get errors. Based on the error, you decide how you should go about cleaning the data

# %% [markdown]
# ##### Drop rows of NAN

# %%
# Find NAN
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())

all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ##### Get rid of text in order date column

# %%
all_data = all_data[all_data['Order Date'].str[0:2]!='Or']

# %% [markdown]
# #### Make columns correct type

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# ### Augment data with additional columns

# %% [markdown]
# #### Add month column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# #### Add month column (alternative method)

# %%
all_data['Month 2'] = pd.to_datetime(all_data['Order Date']).dt.month
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  Month 2
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4        4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4        4

# %% [markdown]
# #### Add city column

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  Month 2  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4        4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4        4
#
#                 City
# 0       Dallas  (TX)
# 2       Boston  (MA)
# 3  Los Angeles  (CA)
# 4  Los Angeles  (CA)
# 5  Los Angeles  (CA)

# %% [markdown]
# ## Data Exploration!

# %% [markdown]
# #### Question 1: What was the best month for sales? How much was earned that month?

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')

# %%
all_data.groupby(['Month']).sum()
# Out:
#        Quantity Ordered  Price Each  Month 2       Sales
# Month
# 1                 10903  1811768.38     9709  1822256.73
# 2                 13449  2188884.72    23950  2202022.42
# 3                 17005  2791207.83    45459  2807100.38
# 4                 20558  3367671.02    73116  3390670.24
# 5                 18667  3135125.13    82830  3152606.75
# 6                 15253  2562025.61    81324  2577802.26
# 7                 16072  2632539.56   100051  2647775.76
# 8                 13448  2230345.42    95688  2244467.88
# 9                 13109  2084992.09   104589  2097560.13
# 10                22703  3715554.83   202820  3736726.88
# 11                19798  3180600.68   193303  3199603.20
# 12                28114  4588415.41   299808  4613443.34

# %%
import matplotlib.pyplot as plt

months = range(1,13)
print(months)

plt.bar(months,all_data.groupby(['Month']).sum()['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# range(1, 13)

# %% [markdown]
# #### Question 2: What city sold the most product?

# %%
all_data.groupby(['City']).sum()
# Out:
#                      Quantity Ordered  Price Each   Month  Month 2       Sales
# City
# Atlanta  (GA)                   16602  2779908.20  104794   104794  2795498.58
# Austin  (TX)                    11153  1809873.61   69829    69829  1819581.75
# Boston  (MA)                    22528  3637409.77  141112   141112  3661642.01
# Dallas  (TX)                    16730  2752627.82  104620   104620  2767975.40
# Los Angeles  (CA)               33289  5421435.23  208325   208325  5452570.80
# New York City  (NY)             27932  4635370.83  175741   175741  4664317.43
# Portland  (ME)                   2750   447189.25   17144    17144   449758.27
# Portland  (OR)                  11303  1860558.22   70621    70621  1870732.34
# San Francisco  (CA)             50239  8211461.74  315520   315520  8262203.91
# Seattle  (WA)                   16553  2733296.01  104941   104941  2747755.48

# %%
import matplotlib.pyplot as plt

keys = [city for city, df in all_data.groupby(['City'])]
print([city for city,h in all_data.groupby(['City'])])

plt.bar(keys,all_data.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)
plt.show()
# Out:
# ['Atlanta  (GA)', 'Austin  (TX)', 'Boston  (MA)', 'Dallas  (TX)', 'Los Angeles  (CA)', 'New York City  (NY)', 'Portland  (ME)', 'Portland  (OR)', 'San Francisco  (CA)', 'Seattle  (WA)']

# %% [markdown]
# #### Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
# Add hour column
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute
all_data['Count'] = 1
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  Month 2  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4        4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4        4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4        4
#
#                 City   Sales  Hour  Minute  Count
# 0       Dallas  (TX)   23.90     8      46      1
# 2       Boston  (MA)   99.99    22      30      1
# 3  Los Angeles  (CA)  600.00    14      38      1
# 4  Los Angeles  (CA)   11.99    14      38      1
# 5  Los Angeles  (CA)   11.99     9      27      1

# %%
keys = [pair for pair, df in all_data.groupby(['Hour'])]
keys = print([pair for pair in all_data.groupby(['Hour'])])

plt.plot(keys, all_data.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()

# My recommendation is slightly before 11am or 7pm
# Out:
# [(0,        Order ID                 Product  Quantity Ordered  Price Each  \
# 20       176575  AAA Batteries (4-pack)                 1        2.99
# 25       176580    USB-C Charging Cable                 1       11.95
# 57       176610  AAA Batteries (4-pack)                 1        2.99
# 114      176667  27in 4K Gaming Monitor                 1      389.99
# 124      176676                LG Dryer                 1      600.00
# ...         ...                     ...               ...         ...
# 186774   259289         ThinkPad Laptop                 1      999.99
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186827   259336  AAA Batteries (4-pack)                 3        2.99
# 186849   259357    USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 20      04/27/19 00:30    433 Hill St, New York City, NY 10001      4
# 25      04/05/19 00:35    886 Willow St, Los Angeles, CA 90001      4
# 57      04/26/19 00:40          382 River St, Dallas, TX 75001      4
# 114     04/11/19 00:39       92 11th St, Los Angeles, CA 90001      4
# 124     04/09/19 00:35   788 Lincoln St, Los Angeles, CA 90001      4
# ...                ...                                     ...    ...
# 186774  09/25/19 00:42   259 Dogwood St, Los Angeles, CA 90001      9
# 186803  09/16/19 00:25      241 Highland St, Atlanta, GA 30301      9
# 186804  09/16/19 00:25      241 Highland St, Atlanta, GA 30301      9
# 186827  09/25/19 00:13           753 14th St, Boston, MA 02215      9
# 186849  09/30/19 00:18  250 Meadow St, San Francisco, CA 94016      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 20            4  New York City  (NY)    2.99     0      30      1
# 25            4    Los Angeles  (CA)   11.95     0      35      1
# 57            4         Dallas  (TX)    2.99     0      40      1
# 114           4    Los Angeles  (CA)  389.99     0      39      1
# 124           4    Los Angeles  (CA)  600.00     0      35      1
# ...         ...                  ...     ...   ...     ...    ...
# 186774        9    Los Angeles  (CA)  999.99     0      42      1
# 186803        9        Atlanta  (GA)   11.99     0      25      1
# 186804        9        Atlanta  (GA)    5.98     0      25      1
# 186827        9         Boston  (MA)    8.97     0      13      1
# 186849        9  San Francisco  (CA)   11.95     0      18      1
#
# [3910 rows x 13 columns]), (1,        Order ID                     Product  Quantity Ordered  Price Each  \
# 95       176648            27in FHD Monitor                 1      149.99
# 187      176737    Apple Airpods Headphones                 1      150.00
# 266      176809  Bose SoundSport Headphones                 2       99.99
# 366      176907            27in FHD Monitor                 1      149.99
# 453      176991  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186445   258976                Google Phone                 1      600.00
# 186447   258978      AAA Batteries (4-pack)                 1        2.99
# 186448   258978        USB-C Charging Cable                 1       11.95
# 186580   259104        USB-C Charging Cable                 1       11.95
# 186706   259224    Lightning Charging Cable                 1       14.95
#
#             Order Date                      Purchase Address  Month  Month 2  \
# 95      04/24/19 01:17        732 2nd St, Portland, OR 97035      4        4
# 187     04/07/19 01:28  109 Center St, Los Angeles, CA 90001      4        4
# 266     04/19/19 01:14  278 13th St, San Francisco, CA 94016      4        4
# 366     04/11/19 01:43  120 Sunset St, Los Angeles, CA 90001      4        4
# 453     04/15/19 01:49   338 2nd St, San Francisco, CA 94016      4        4
# ...                ...                                   ...    ...      ...
# 186445  09/27/19 01:54         211 13th St, Dallas, TX 75001      9        9
# 186447  09/18/19 01:00    663 Dogwood St, Portland, OR 97035      9        9
# 186448  09/18/19 01:00    663 Dogwood St, Portland, OR 97035      9        9
# 186580  09/19/19 01:33     824 7th St, Los Angeles, CA 90001      9        9
# 186706  09/25/19 01:08     588 2nd St, Los Angeles, CA 90001      9        9
#
#                        City   Sales  Hour  Minute  Count
# 95           Portland  (OR)  149.99     1      17      1
# 187       Los Angeles  (CA)  150.00     1      28      1
# 266     San Francisco  (CA)  199.98     1      14      1
# 366       Los Angeles  (CA)  149.99     1      43      1
# 453     San Francisco  (CA)   99.99     1      49      1
# ...                     ...     ...   ...     ...    ...
# 186445         Dallas  (TX)  600.00     1      54      1
# 186447       Portland  (OR)    2.99     1       0      1
# 186448       Portland  (OR)   11.95     1       0      1
# 186580    Los Angeles  (CA)   11.95     1      33      1
# 186706    Los Angeles  (CA)   14.95     1       8      1
#
# [2350 rows x 13 columns]), (2,        Order ID                   Product  Quantity Ordered  Price Each  \
# 91       176644      USB-C Charging Cable                 1       11.95
# 276      176818          Wired Headphones                 1       11.99
# 405      176945      USB-C Charging Cable                 1       11.95
# 547      177082    34in Ultrawide Monitor                 1      379.99
# 691      177214    AAA Batteries (4-pack)                 2        2.99
# ...         ...                       ...               ...         ...
# 186377   258910        Macbook Pro Laptop                 1     1700.00
# 186496   259024    AAA Batteries (4-pack)                 2        2.99
# 186710   259228     AA Batteries (4-pack)                 1        3.84
# 186730   259248  Apple Airpods Headphones                 1      150.00
# 186739   259256      USB-C Charging Cable                 2       11.95
#
#             Order Date                        Purchase Address  Month  \
# 91      04/23/19 02:09       962 7th St, Los Angeles, CA 90001      4
# 276     04/09/19 02:19    642 13th St, San Francisco, CA 94016      4
# 405     04/24/19 02:17           701 Pine St, Austin, TX 73301      4
# 547     04/12/19 02:30        15 Johnson St, Seattle, WA 98101      4
# 691     04/09/19 02:05           616 9th St, Seattle, WA 98101      4
# ...                ...                                     ...    ...
# 186377  09/27/19 02:27           703 Lake St, Boston, MA 02215      9
# 186496  09/18/19 02:43  754 Sunset St, New York City, NY 10001      9
# 186710  10/01/19 02:55        71 2nd St, Los Angeles, CA 90001     10
# 186730  09/27/19 02:25         368 Adams St, Atlanta, GA 30301      9
# 186739  09/18/19 02:32        947 Center St, Seattle, WA 98101      9
#
#         Month 2                 City    Sales  Hour  Minute  Count
# 91            4    Los Angeles  (CA)    11.95     2       9      1
# 276           4  San Francisco  (CA)    11.99     2      19      1
# 405           4         Austin  (TX)    11.95     2      17      1
# 547           4        Seattle  (WA)   379.99     2      30      1
# 691           4        Seattle  (WA)     5.98     2       5      1
# ...         ...                  ...      ...   ...     ...    ...
# 186377        9         Boston  (MA)  1700.00     2      27      1
# 186496        9  New York City  (NY)     5.98     2      43      1
# 186710       10    Los Angeles  (CA)     3.84     2      55      1
# 186730        9        Atlanta  (GA)   150.00     2      25      1
# 186739        9        Seattle  (WA)    23.90     2      32      1
#
# [1243 rows x 13 columns]), (3,        Order ID                   Product  Quantity Ordered  Price Each  \
# 439      176978  Apple Airpods Headphones                 1      150.00
# 991      177501          Wired Headphones                 1       11.99
# 1341     177831  Lightning Charging Cable                 1       14.95
# 1596     178077           ThinkPad Laptop                 1      999.99
# 1821     178288  Lightning Charging Cable                 1       14.95
# ...         ...                       ...               ...         ...
# 185115   257697  Apple Airpods Headphones                 1      150.00
# 185704   258266      USB-C Charging Cable                 1       11.95
# 185744   258304          Wired Headphones                 1       11.99
# 185882   258437          Wired Headphones                 1       11.99
# 186554   259079    27in 4K Gaming Monitor                 1      389.99
#
#             Order Date                       Purchase Address  Month  Month 2  \
# 439     05/01/19 03:29        589 Lake St, Portland, OR 97035      5        5
# 991     04/10/19 03:43         888 14th St, Seattle, WA 98101      4        4
# 1341    04/01/19 03:09    914 6th St, San Francisco, CA 94016      4        4
# 1596    04/06/19 03:09   771 14th St, San Francisco, CA 94016      4        4
# 1821    04/03/19 03:22           102 8th St, Dallas, TX 75001      4        4
# ...                ...                                    ...    ...      ...
# 185115  09/10/19 03:12  418 Jackson St, Los Angeles, CA 90001      9        9
# 185704  09/02/19 03:36   412 Cherry St, Los Angeles, CA 90001      9        9
# 185744  09/30/19 03:46           969 Elm St, Boston, MA 02215      9        9
# 185882  09/10/19 03:51  529 River St, San Francisco, CA 94016      9        9
# 186554  09/27/19 03:07  13 Forest St, New York City, NY 10001      9        9
#
#                        City   Sales  Hour  Minute  Count
# 439          Portland  (OR)  150.00     3      29      1
# 991           Seattle  (WA)   11.99     3      43      1
# 1341    San Francisco  (CA)   14.95     3       9      1
# 1596    San Francisco  (CA)  999.99     3       9      1
# 1821           Dallas  (TX)   14.95     3      22      1
# ...                     ...     ...   ...     ...    ...
# 185115    Los Angeles  (CA)  150.00     3      12      1
# 185704    Los Angeles  (CA)   11.95     3      36      1
# 185744         Boston  (MA)   11.99     3      46      1
# 185882  San Francisco  (CA)   11.99     3      51      1
# 186554  New York City  (NY)  389.99     3       7      1
#
# [831 rows x 13 columns]), (4,        Order ID                     Product  Quantity Ordered  Price Each  \
# 35       176588                20in Monitor                 1      109.99
# 75       176628    Lightning Charging Cable                 2       14.95
# 241      176788  Bose SoundSport Headphones                 1       99.99
# 1188     177687            Wired Headphones                 1       11.99
# 1418     177906                Google Phone                 1      600.00
# ...         ...                         ...               ...         ...
# 184949   257538                Google Phone                 1      600.00
# 184950   257538            Wired Headphones                 1       11.99
# 185430   258001            27in FHD Monitor                 1      149.99
# 186168   258711    Lightning Charging Cable                 1       14.95
# 186555   259080    Apple Airpods Headphones                 1      150.00
#
#             Order Date                        Purchase Address  Month  \
# 35      04/02/19 04:00        765 Cherry St, Seattle, WA 98101      4
# 75      04/15/19 04:03         628 Wilson St, Dallas, TX 75001      4
# 241     04/15/19 04:39   200 North St, New York City, NY 10001      4
# 1188    04/01/19 04:12   23 Meadow St, San Francisco, CA 94016      4
# 1418    04/15/19 04:59  876 Wilson St, New York City, NY 10001      4
# ...                ...                                     ...    ...
# 184949  09/22/19 04:37     914 2nd St, San Francisco, CA 94016      9
# 184950  09/22/19 04:37     914 2nd St, San Francisco, CA 94016      9
# 185430  09/23/19 04:17          463 Park St, Seattle, WA 98101      9
# 186168  09/04/19 04:17  906 Highland St, Los Angeles, CA 90001      9
# 186555  09/24/19 04:04         268 Ridge St, Seattle, WA 98101      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 35            4        Seattle  (WA)  109.99     4       0      1
# 75            4         Dallas  (TX)   29.90     4       3      1
# 241           4  New York City  (NY)   99.99     4      39      1
# 1188          4  San Francisco  (CA)   11.99     4      12      1
# 1418          4  New York City  (NY)  600.00     4      59      1
# ...         ...                  ...     ...   ...     ...    ...
# 184949        9  San Francisco  (CA)  600.00     4      37      1
# 184950        9  San Francisco  (CA)   11.99     4      37      1
# 185430        9        Seattle  (WA)  149.99     4      17      1
# 186168        9    Los Angeles  (CA)   14.95     4      17      1
# 186555        9        Seattle  (WA)  150.00     4       4      1
#
# [854 rows x 13 columns]), (5,        Order ID                Product  Quantity Ordered  Price Each  \
# 77       176630           Google Phone                 1      600.00
# 162      176712           Google Phone                 1      600.00
# 277      176819  AA Batteries (4-pack)                 2        3.84
# 331      176873  AA Batteries (4-pack)                 1        3.84
# 437      176976       27in FHD Monitor                 1      149.99
# ...         ...                    ...               ...         ...
# 186637   259157     Macbook Pro Laptop                 1     1700.00
# 186650   259170       Wired Headphones                 1       11.99
# 186700   259218   USB-C Charging Cable                 1       11.95
# 186749   259266   USB-C Charging Cable                 1       11.95
# 186780   259295  AA Batteries (4-pack)                 1        3.84
#
#             Order Date                            Purchase Address  Month  \
# 77      04/10/19 05:01       770 Maple St, San Francisco, CA 94016      4
# 162     04/20/19 05:21  910 Washington St, San Francisco, CA 94016      4
# 277     04/15/19 05:44              615 9th St, Portland, OR 97035      4
# 331     04/06/19 05:26        532 Spruce St, Los Angeles, CA 90001      4
# 437     04/18/19 05:42          260 Pine St, Los Angeles, CA 90001      4
# ...                ...                                         ...    ...
# 186637  09/12/19 05:01            326 Forest St, Seattle, WA 98101      9
# 186650  09/19/19 05:04       755 Maple St, New York City, NY 10001      9
# 186700  09/30/19 05:13            522 Dogwood St, Dallas, TX 75001      9
# 186749  09/13/19 05:36           9 2nd St, New York City, NY 10001      9
# 186780  09/11/19 05:09       263 River St, San Francisco, CA 94016      9
#
#         Month 2                 City    Sales  Hour  Minute  Count
# 77            4  San Francisco  (CA)   600.00     5       1      1
# 162           4  San Francisco  (CA)   600.00     5      21      1
# 277           4       Portland  (OR)     7.68     5      44      1
# 331           4    Los Angeles  (CA)     3.84     5      26      1
# 437           4    Los Angeles  (CA)   149.99     5      42      1
# ...         ...                  ...      ...   ...     ...    ...
# 186637        9        Seattle  (WA)  1700.00     5       1      1
# 186650        9  New York City  (NY)    11.99     5       4      1
# 186700        9         Dallas  (TX)    11.95     5      13      1
# 186749        9  New York City  (NY)    11.95     5      36      1
# 186780        9  San Francisco  (CA)     3.84     5       9      1
#
# [1321 rows x 13 columns]), (6,        Order ID                     Product  Quantity Ordered  Price Each  \
# 131      176682    Lightning Charging Cable                 1       14.95
# 359      176900  Bose SoundSport Headphones                 1       99.99
# 403      176943    Lightning Charging Cable                 1       14.95
# 404      176944  Bose SoundSport Headphones                 1       99.99
# 506      177042    Lightning Charging Cable                 1       14.95
# ...         ...                         ...               ...         ...
# 186566   259090      34in Ultrawide Monitor                 1      379.99
# 186588   259112       AA Batteries (4-pack)                 4        3.84
# 186662   259182            Wired Headphones                 2       11.99
# 186755   259271               Flatscreen TV                 1      300.00
# 186795   259306    Apple Airpods Headphones                 1      150.00
#
#             Order Date                       Purchase Address  Month  Month 2  \
# 131     04/27/19 06:19         593 Adams St, Boston, MA 02215      4        4
# 359     04/21/19 06:17         356 North St, Boston, MA 02215      4        4
# 403     04/09/19 06:50    211 2nd St, San Francisco, CA 94016      4        4
# 404     04/28/19 06:22          719 West St, Austin, TX 73301      4        4
# 506     04/24/19 06:57   876 Hill St, San Francisco, CA 94016      4        4
# ...                ...                                    ...    ...      ...
# 186566  09/10/19 06:48  505 North St, New York City, NY 10001      9        9
# 186588  09/10/19 06:25     272 Hill St, Los Angeles, CA 90001      9        9
# 186662  09/23/19 06:48           119 2nd St, Dallas, TX 75001      9        9
# 186755  09/15/19 06:03         453 Hill St, Seattle, WA 98101      9        9
# 186795  09/02/19 06:40   962 13th St, New York City, NY 10001      9        9
#
#                        City   Sales  Hour  Minute  Count
# 131            Boston  (MA)   14.95     6      19      1
# 359            Boston  (MA)   99.99     6      17      1
# 403     San Francisco  (CA)   14.95     6      50      1
# 404            Austin  (TX)   99.99     6      22      1
# 506     San Francisco  (CA)   14.95     6      57      1
# ...                     ...     ...   ...     ...    ...
# 186566  New York City  (NY)  379.99     6      48      1
# 186588    Los Angeles  (CA)   15.36     6      25      1
# 186662         Dallas  (TX)   23.98     6      48      1
# 186755        Seattle  (WA)  300.00     6       3      1
# 186795  New York City  (NY)  150.00     6      40      1
#
# [2482 rows x 13 columns]), (7,        Order ID                     Product  Quantity Ordered  Price Each  \
# 7        176563  Bose SoundSport Headphones                 1       99.99
# 38       176591    Apple Airpods Headphones                 1      150.00
# 50       176603        USB-C Charging Cable                 1       11.95
# 93       176646          Macbook Pro Laptop                 1     1700.00
# 178      176728    Lightning Charging Cable                 1       14.95
# ...         ...                         ...               ...         ...
# 186722   259240        USB-C Charging Cable                 1       11.95
# 186763   259278                      iPhone                 1      700.00
# 186790   259302      AAA Batteries (4-pack)                 1        2.99
# 186821   259331    Apple Airpods Headphones                 1      150.00
# 186847   259355                      iPhone                 1      700.00
#
#             Order Date                      Purchase Address  Month  Month 2  \
# 7       04/02/19 07:46      668 Center St, Seattle, WA 98101      4        4
# 38      04/21/19 07:21        600 Maple St, Austin, TX 73301      4        4
# 50      04/01/19 07:46   858 6th St, San Francisco, CA 94016      4        4
# 93      04/22/19 07:14      657 Adams St, Portland, OR 97035      4        4
# 178     04/21/19 07:38        516 Park St, Atlanta, GA 30301      4        4
# ...                ...                                   ...    ...      ...
# 186722  09/22/19 07:46       737 Spruce St, Boston, MA 02215      9        9
# 186763  09/11/19 07:24     505 Hickory St, Atlanta, GA 30301      9        9
# 186790  09/16/19 07:27   364 4th St, San Francisco, CA 94016      9        9
# 186821  09/29/19 07:00   770 4th St, New York City, NY 10001      9        9
# 186847  09/23/19 07:39  220 12th St, San Francisco, CA 94016      9        9
#
#                        City    Sales  Hour  Minute  Count
# 7             Seattle  (WA)    99.99     7      46      1
# 38             Austin  (TX)   150.00     7      21      1
# 50      San Francisco  (CA)    11.95     7      46      1
# 93           Portland  (OR)  1700.00     7      14      1
# 178           Atlanta  (GA)    14.95     7      38      1
# ...                     ...      ...   ...     ...    ...
# 186722         Boston  (MA)    11.95     7      46      1
# 186763        Atlanta  (GA)   700.00     7      24      1
# 186790  San Francisco  (CA)     2.99     7      27      1
# 186821  New York City  (NY)   150.00     7       0      1
# 186847  San Francisco  (CA)   700.00     7      39      1
#
# [4011 rows x 13 columns]), (8,        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 64       176617    Apple Airpods Headphones                 1      150.00
# 81       176634    Lightning Charging Cable                 1       14.95
# 85       176638        USB-C Charging Cable                 1       11.95
# 96       176649        USB-C Charging Cable                 1       11.95
# ...         ...                         ...               ...         ...
# 186630   259151       AA Batteries (4-pack)                 1        3.84
# 186641   259161       AA Batteries (4-pack)                 1        3.84
# 186647   259167    Apple Airpods Headphones                 1      150.00
# 186682   259202  Bose SoundSport Headphones                 1       99.99
# 186765   259280    Lightning Charging Cable                 1       14.95
#
#             Order Date                      Purchase Address  Month  Month 2  \
# 0       04/19/19 08:46          917 1st St, Dallas, TX 75001      4        4
# 64      04/25/19 08:03        319 8th St, Portland, OR 97035      4        4
# 81      04/10/19 08:00     311 Madison St, Atlanta, GA 30301      4        4
# 85      04/20/19 08:33       869 Cherry St, Boston, MA 02215      4        4
# 96      04/09/19 08:49  702 11th St, San Francisco, CA 94016      4        4
# ...                ...                                   ...    ...      ...
# 186630  09/12/19 08:09    308 11th St, Los Angeles, CA 90001      9        9
# 186641  09/06/19 08:19  524 Forest St, Los Angeles, CA 90001      9        9
# 186647  09/12/19 08:45   483 8th St, New York City, NY 10001      9        9
# 186682  09/12/19 08:58       692 Pine St, Portland, OR 97035      9        9
# 186765  09/13/19 08:58  619 10th St, San Francisco, CA 94016      9        9
#
#                        City   Sales  Hour  Minute  Count
# 0              Dallas  (TX)   23.90     8      46      1
# 64           Portland  (OR)  150.00     8       3      1
# 81            Atlanta  (GA)   14.95     8       0      1
# 85             Boston  (MA)   11.95     8      33      1
# 96      San Francisco  (CA)   11.95     8      49      1
# ...                     ...     ...   ...     ...    ...
# 186630    Los Angeles  (CA)    3.84     8       9      1
# 186641    Los Angeles  (CA)    3.84     8      19      1
# 186647  New York City  (NY)  150.00     8      45      1
# 186682       Portland  (OR)   99.99     8      58      1
# 186765  San Francisco  (CA)   14.95     8      58      1
#
# [6256 rows x 13 columns]), (9,        Order ID                   Product  Quantity Ordered  Price Each  \
# 5        176561          Wired Headphones                 1       11.99
# 42       176595          Wired Headphones                 3       11.99
# 49       176602  Lightning Charging Cable                 1       14.95
# 82       176635           Vareebadd Phone                 1      400.00
# 123      176675    AAA Batteries (4-pack)                 1        2.99
# ...         ...                       ...               ...         ...
# 186640   259160  Lightning Charging Cable                 1       14.95
# 186646   259166    27in 4K Gaming Monitor                 1      389.99
# 186732   259250          27in FHD Monitor                 1      149.99
# 186769   259284     AA Batteries (4-pack)                 1        3.84
# 186786   259298              20in Monitor                 1      109.99
#
#             Order Date                         Purchase Address  Month  \
# 5       04/30/19 09:27        333 8th St, Los Angeles, CA 90001      4
# 42      04/02/19 09:11        383 6th St, Los Angeles, CA 90001      4
# 49      04/30/19 09:39         9 Jefferson St, Dallas, TX 75001      4
# 82      04/26/19 09:55     85 North St, San Francisco, CA 94016      4
# 123     04/02/19 09:02         933 Meadow St, Seattle, WA 98101      4
# ...                ...                                      ...    ...
# 186640  09/30/19 09:43        402 2nd St, Los Angeles, CA 90001      9
# 186646  09/23/19 09:46  982 Lincoln St, New York City, NY 10001      9
# 186732  09/15/19 09:31       460 Park St, Los Angeles, CA 90001      9
# 186769  09/18/19 09:55     97 Jackson St, Los Angeles, CA 90001      9
# 186786  09/18/19 09:10            188 11th St, Austin, TX 73301      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 5             4    Los Angeles  (CA)   11.99     9      27      1
# 42            4    Los Angeles  (CA)   35.97     9      11      1
# 49            4         Dallas  (TX)   14.95     9      39      1
# 82            4  San Francisco  (CA)  400.00     9      55      1
# 123           4        Seattle  (WA)    2.99     9       2      1
# ...         ...                  ...     ...   ...     ...    ...
# 186640        9    Los Angeles  (CA)   14.95     9      43      1
# 186646        9  New York City  (NY)  389.99     9      46      1
# 186732        9    Los Angeles  (CA)  149.99     9      31      1
# 186769        9    Los Angeles  (CA)    3.84     9      55      1
# 186786        9         Austin  (TX)  109.99     9      10      1
#
# [8748 rows x 13 columns]), (10,        Order ID                     Product  Quantity Ordered  Price Each  \
# 8        176564        USB-C Charging Cable                 1       11.95
# 9        176565          Macbook Pro Laptop                 1     1700.00
# 24       176579       AA Batteries (4-pack)                 1        3.84
# 51       176604        USB-C Charging Cable                 1       11.95
# 62       176615    Lightning Charging Cable                 1       14.95
# ...         ...                         ...               ...         ...
# 186810   259320             ThinkPad Laptop                 1      999.99
# 186812   259322  Bose SoundSport Headphones                 1       99.99
# 186818   259328            Wired Headphones                 1       11.99
# 186824   259334        USB-C Charging Cable                 1       11.95
# 186838   259347       AA Batteries (4-pack)                 1        3.84
#
#             Order Date                           Purchase Address  Month  \
# 8       04/12/19 10:58            790 Ridge St, Atlanta, GA 30301      4
# 9       04/24/19 10:38     915 Willow St, San Francisco, CA 94016      4
# 24      04/11/19 10:23  886 Jefferson St, New York City, NY 10001      4
# 51      04/02/19 10:57       462 11th St, San Francisco, CA 94016      4
# 62      04/30/19 10:35             833 River St, Dallas, TX 75001      4
# ...                ...                                        ...    ...
# 186810  09/02/19 10:51              857 Elm St, Atlanta, GA 30301      9
# 186812  09/15/19 10:45          401 7th St, Los Angeles, CA 90001      9
# 186818  09/18/19 10:13           877 Lincoln St, Boston, MA 02215      9
# 186824  09/27/19 10:52             276 14th St, Atlanta, GA 30301      9
# 186838  09/26/19 10:12      979 Madison St, Los Angeles, CA 90001      9
#
#         Month 2                 City    Sales  Hour  Minute  Count
# 8             4        Atlanta  (GA)    11.95    10      58      1
# 9             4  San Francisco  (CA)  1700.00    10      38      1
# 24            4  New York City  (NY)     3.84    10      23      1
# 51            4  San Francisco  (CA)    11.95    10      57      1
# 62            4         Dallas  (TX)    14.95    10      35      1
# ...         ...                  ...      ...   ...     ...    ...
# 186810        9        Atlanta  (GA)   999.99    10      51      1
# 186812        9    Los Angeles  (CA)    99.99    10      45      1
# 186818        9         Boston  (MA)    11.99    10      13      1
# 186824        9        Atlanta  (GA)    11.95    10      52      1
# 186838        9    Los Angeles  (CA)     3.84    10      12      1
#
# [10944 rows x 13 columns]), (11,        Order ID                     Product  Quantity Ordered  Price Each  \
# 21       176576    Apple Airpods Headphones                 1      150.00
# 30       176585  Bose SoundSport Headphones                 1       99.99
# 31       176585  Bose SoundSport Headphones                 1       99.99
# 37       176590                Google Phone                 1      600.00
# 76       176629        USB-C Charging Cable                 1       11.95
# ...         ...                         ...               ...         ...
# 186770   259285       AA Batteries (4-pack)                 1        3.84
# 186778   259293            Wired Headphones                 1       11.99
# 186779   259294            27in FHD Monitor                 1      149.99
# 186802   259313  Bose SoundSport Headphones                 1       99.99
# 186815   259325        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# 21      04/28/19 11:42      771 Ridge St, Los Angeles, CA 90001      4
# 30      04/07/19 11:31        823 Highland St, Boston, MA 02215      4
# 31      04/07/19 11:31        823 Highland St, Boston, MA 02215      4
# 37      04/11/19 11:46      873 6th St, New York City, NY 10001      4
# 76      04/24/19 11:56  101 Lincoln St, San Francisco, CA 94016      4
# ...                ...                                      ...    ...
# 186770  09/07/19 11:22      990 9th St, San Francisco, CA 94016      9
# 186778  09/02/19 11:37    678 Adams St, San Francisco, CA 94016      9
# 186779  09/16/19 11:02          796 Walnut St, Austin, TX 73301      9
# 186802  09/05/19 11:34        138 2nd St, Los Angeles, CA 90001      9
# 186815  09/25/19 11:51       83 7th St, New York City, NY 10001      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 21            4    Los Angeles  (CA)  150.00    11      42      1
# 30            4         Boston  (MA)   99.99    11      31      1
# 31            4         Boston  (MA)   99.99    11      31      1
# 37            4  New York City  (NY)  600.00    11      46      1
# 76            4  San Francisco  (CA)   11.95    11      56      1
# ...         ...                  ...     ...   ...     ...    ...
# 186770        9  San Francisco  (CA)    3.84    11      22      1
# 186778        9  San Francisco  (CA)   11.99    11      37      1
# 186779        9         Austin  (TX)  149.99    11       2      1
# 186802        9    Los Angeles  (CA)   99.99    11      34      1
# 186815        9  New York City  (NY)   11.95    11      51      1
#
# [12411 rows x 13 columns]), (12,        Order ID                     Product  Quantity Ordered  Price Each  \
# 12       176568    Lightning Charging Cable                 1       14.95
# 27       176582  Bose SoundSport Headphones                 1       99.99
# 28       176583      AAA Batteries (4-pack)                 2        2.99
# 36       176589    Lightning Charging Cable                 1       14.95
# 54       176607      AAA Batteries (4-pack)                 2        2.99
# ...         ...                         ...               ...         ...
# 186674   259194            27in FHD Monitor                 1      149.99
# 186692   259210    Lightning Charging Cable                 1       14.95
# 186733   259251            Wired Headphones                 1       11.99
# 186798   259309            Wired Headphones                 1       11.99
# 186809   259319      27in 4K Gaming Monitor                 1      389.99
#
#             Order Date                         Purchase Address  Month  \
# 12      04/15/19 12:18            438 Elm St, Seattle, WA 98101      4
# 27      04/27/19 12:20        178 Lincoln St, Atlanta, GA 30301      4
# 28      04/20/19 12:00       146 Jackson St, Portland, OR 97035      4
# 36      04/04/19 12:23       846 Highland St, Atlanta, GA 30301      4
# 54      04/18/19 12:11            689 10th St, Boston, MA 02215      4
# ...                ...                                      ...    ...
# 186674  09/03/19 12:13          543 Center St, Austin, TX 73301      9
# 186692  09/27/19 12:35        132 Meadow St, Portland, ME 04101      9
# 186733  09/18/19 12:01            320 Main St, Austin, TX 73301      9
# 186798  09/09/19 12:55          865 Ridge St, Atlanta, GA 30301      9
# 186809  09/15/19 12:30  811 Lincoln St, San Francisco, CA 94016      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 12            4        Seattle  (WA)   14.95    12      18      1
# 27            4        Atlanta  (GA)   99.99    12      20      1
# 28            4       Portland  (OR)    5.98    12       0      1
# 36            4        Atlanta  (GA)   14.95    12      23      1
# 54            4         Boston  (MA)    5.98    12      11      1
# ...         ...                  ...     ...   ...     ...    ...
# 186674        9         Austin  (TX)  149.99    12      13      1
# 186692        9       Portland  (ME)   14.95    12      35      1
# 186733        9         Austin  (TX)   11.99    12       1      1
# 186798        9        Atlanta  (GA)   11.99    12      55      1
# 186809        9  San Francisco  (CA)  389.99    12      30      1
#
# [12587 rows x 13 columns]), (13,        Order ID                     Product  Quantity Ordered  Price Each  \
# 6        176562        USB-C Charging Cable                 1       11.95
# 39       176592        USB-C Charging Cable                 1       11.95
# 40       176593    Lightning Charging Cable                 2       14.95
# 44       176597        USB-C Charging Cable                 1       11.95
# 58       176611  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186762   259277            Wired Headphones                 2       11.99
# 186777   259292      27in 4K Gaming Monitor                 1      389.99
# 186814   259324          Macbook Pro Laptop                 1     1700.00
# 186841   259350                Google Phone                 1      600.00
# 186842   259350        USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 6       04/29/19 13:03  381 Wilson St, San Francisco, CA 94016      4
# 39      04/27/19 13:04       352 4th St, Los Angeles, CA 90001      4
# 40      04/15/19 13:45          906 7th St, Portland, OR 97035      4
# 44      04/19/19 13:39    681 11th St, San Francisco, CA 94016      4
# 58      04/30/19 13:16  971 Sunset St, San Francisco, CA 94016      4
# ...                ...                                     ...    ...
# 186762  09/28/19 13:07  795 Willow St, New York City, NY 10001      9
# 186777  09/07/19 13:47  66 Hickory St, San Francisco, CA 94016      9
# 186814  09/29/19 13:37   926 North St, San Francisco, CA 94016      9
# 186841  09/30/19 13:49   519 Maple St, San Francisco, CA 94016      9
# 186842  09/30/19 13:49   519 Maple St, San Francisco, CA 94016      9
#
#         Month 2                 City    Sales  Hour  Minute  Count
# 6             4  San Francisco  (CA)    11.95    13       3      1
# 39            4    Los Angeles  (CA)    11.95    13       4      1
# 40            4       Portland  (OR)    29.90    13      45      1
# 44            4  San Francisco  (CA)    11.95    13      39      1
# 58            4  San Francisco  (CA)    99.99    13      16      1
# ...         ...                  ...      ...   ...     ...    ...
# 186762        9  New York City  (NY)    23.98    13       7      1
# 186777        9  San Francisco  (CA)   389.99    13      47      1
# 186814        9  San Francisco  (CA)  1700.00    13      37      1
# 186841        9  San Francisco  (CA)   600.00    13      49      1
# 186842        9  San Francisco  (CA)    11.95    13      49      1
#
# [12129 rows x 13 columns]), (14,        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 10       176566            Wired Headphones                 1       11.99
# 15       176571    Lightning Charging Cable                 1       14.95
# 53       176606                    LG Dryer                 1      600.00
# ...         ...                         ...               ...         ...
# 186736   259254             Vareebadd Phone                 1      400.00
# 186747   259264      27in 4K Gaming Monitor                 1      389.99
# 186764   259279  Bose SoundSport Headphones                 1       99.99
# 186789   259301    Apple Airpods Headphones                 1      150.00
# 186800   259311               Flatscreen TV                 1      300.00
#
#             Order Date                         Purchase Address  Month  \
# 3       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4
# 4       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001      4
# 10      04/08/19 14:05              83 7th St, Boston, MA 02215      4
# 15      04/19/19 14:29        253 Johnson St, Atlanta, GA 30301      4
# 53      04/21/19 14:16    487 Maple St, San Francisco, CA 94016      4
# ...                ...                                      ...    ...
# 186736  09/06/19 14:02        853 5th St, Los Angeles, CA 90001      9
# 186747  09/03/19 14:42            349 West St, Boston, MA 02215      9
# 186764  09/22/19 14:45       57 Elm St, New York City, NY 10001      9
# 186789  09/13/19 14:03  963 Jackson St, San Francisco, CA 94016      9
# 186800  09/18/19 14:54          930 North St, Seattle, WA 98101      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 3             4    Los Angeles  (CA)  600.00    14      38      1
# 4             4    Los Angeles  (CA)   11.99    14      38      1
# 10            4         Boston  (MA)   11.99    14       5      1
# 15            4        Atlanta  (GA)   14.95    14      29      1
# 53            4  San Francisco  (CA)  600.00    14      16      1
# ...         ...                  ...     ...   ...     ...    ...
# 186736        9    Los Angeles  (CA)  400.00    14       2      1
# 186747        9         Boston  (MA)  389.99    14      42      1
# 186764        9  New York City  (NY)   99.99    14      45      1
# 186789        9  San Francisco  (CA)  150.00    14       3      1
# 186800        9        Seattle  (WA)  300.00    14      54      1
#
# [10984 rows x 13 columns]), (15,        Order ID                     Product  Quantity Ordered  Price Each  \
# 14       176570       AA Batteries (4-pack)                 1        3.84
# 46       176599    Lightning Charging Cable                 1       14.95
# 47       176600      27in 4K Gaming Monitor                 1      389.99
# 135      176686            Wired Headphones                 1       11.99
# 191      176740  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186725   259243      27in 4K Gaming Monitor                 1      389.99
# 186728   259246  Bose SoundSport Headphones                 1       99.99
# 186753   259270                Google Phone                 1      600.00
# 186754   259270        USB-C Charging Cable                 1       11.95
# 186844   259352        USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# 14      04/22/19 15:09           186 12th St, Dallas, TX 75001      4
# 46      04/11/19 15:25   279 Maple St, New York City, NY 10001      4
# 47      04/30/19 15:54            87 West St, Boston, MA 02215      4
# 135     04/17/19 15:17           892 10th St, Austin, TX 73301      4
# 191     04/24/19 15:10     699 Washington St, Dallas, TX 75001      4
# ...                ...                                     ...    ...
# 186725  09/14/19 15:36    815 Church St, Los Angeles, CA 90001      9
# 186728  09/04/19 15:55  777 Forest St, San Francisco, CA 94016      9
# 186753  09/06/19 15:27    940 10th St, San Francisco, CA 94016      9
# 186754  09/06/19 15:27    940 10th St, San Francisco, CA 94016      9
# 186844  09/07/19 15:49  976 Forest St, San Francisco, CA 94016      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 14            4         Dallas  (TX)    3.84    15       9      1
# 46            4  New York City  (NY)   14.95    15      25      1
# 47            4         Boston  (MA)  389.99    15      54      1
# 135           4         Austin  (TX)   11.99    15      17      1
# 191           4         Dallas  (TX)   99.99    15      10      1
# ...         ...                  ...     ...   ...     ...    ...
# 186725        9    Los Angeles  (CA)  389.99    15      36      1
# 186728        9  San Francisco  (CA)   99.99    15      55      1
# 186753        9  San Francisco  (CA)  600.00    15      27      1
# 186754        9  San Francisco  (CA)   11.95    15      27      1
# 186844        9  San Francisco  (CA)   11.95    15      49      1
#
# [10175 rows x 13 columns]), (16,        Order ID                   Product  Quantity Ordered  Price Each  \
# 52       176605      USB-C Charging Cable                 1       11.95
# 56       176609  Apple Airpods Headphones                 1      150.00
# 68       176621  Lightning Charging Cable                 1       14.95
# 86       176639        Macbook Pro Laptop                 1     1700.00
# 97       176650  Lightning Charging Cable                 1       14.95
# ...         ...                       ...               ...         ...
# 186805   259315  Lightning Charging Cable                 1       14.95
# 186806   259316    AAA Batteries (4-pack)                 1        2.99
# 186811   259321           ThinkPad Laptop                 1      999.99
# 186813   259323      USB-C Charging Cable                 1       11.95
# 186846   259354                    iPhone                 1      700.00
#
#             Order Date                         Purchase Address  Month  \
# 52      04/15/19 16:29     717 Pine St, San Francisco, CA 94016      4
# 56      04/11/19 16:59            267 11th St, Austin, TX 73301      4
# 68      04/11/19 16:09             863 8th St, Boston, MA 02215      4
# 86      04/28/19 16:14    853 Cedar St, San Francisco, CA 94016      4
# 97      04/12/19 16:47           153 River St, Boston, MA 02215      4
# ...                ...                                      ...    ...
# 186805  09/29/19 16:20             112 5th St, Boston, MA 02215      9
# 186806  09/16/19 16:48        369 Johnson St, Atlanta, GA 30301      9
# 186811  09/25/19 16:09    418 Hickory St, Los Angeles, CA 90001      9
# 186813  09/24/19 16:42        727 Forest St, Portland, OR 97035      9
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016      9
#
#         Month 2                 City    Sales  Hour  Minute  Count
# 52            4  San Francisco  (CA)    11.95    16      29      1
# 56            4         Austin  (TX)   150.00    16      59      1
# 68            4         Boston  (MA)    14.95    16       9      1
# 86            4  San Francisco  (CA)  1700.00    16      14      1
# 97            4         Boston  (MA)    14.95    16      47      1
# ...         ...                  ...      ...   ...     ...    ...
# 186805        9         Boston  (MA)    14.95    16      20      1
# 186806        9        Atlanta  (GA)     2.99    16      48      1
# 186811        9    Los Angeles  (CA)   999.99    16       9      1
# 186813        9       Portland  (OR)    11.95    16      42      1
# 186846        9  San Francisco  (CA)   700.00    16       0      1
#
# [10384 rows x 13 columns]), (17,        Order ID                     Product  Quantity Ordered  Price Each  \
# 11       176567                Google Phone                 1      600.00
# 32       176586      AAA Batteries (4-pack)                 2        2.99
# 33       176586                Google Phone                 1      600.00
# 107      176660       AA Batteries (4-pack)                 1        3.84
# 138      176689  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186766   259281            27in FHD Monitor                 1      149.99
# 186825   259335    Lightning Charging Cable                 1       14.95
# 186828   259337        USB-C Charging Cable                 1       11.95
# 186837   259346  Bose SoundSport Headphones                 1       99.99
# 186848   259356      34in Ultrawide Monitor                 1      379.99
#
#             Order Date                         Purchase Address  Month  \
# 11      04/18/19 17:18        444 7th St, Los Angeles, CA 90001      4
# 32      04/10/19 17:00   365 Center St, San Francisco, CA 94016      4
# 33      04/10/19 17:00   365 Center St, San Francisco, CA 94016      4
# 107     04/16/19 17:10            267 West St, Boston, MA 02215      4
# 138     04/24/19 17:15  659 Lincoln St, New York City, NY 10001      4
# ...                ...                                      ...    ...
# 186766  09/22/19 17:19         755 Dogwood St, Dallas, TX 75001      9
# 186825  09/26/19 17:21         791 Forest St, Seattle, WA 98101      9
# 186828  09/19/19 17:34            495 Park St, Boston, MA 02215      9
# 186837  09/29/19 17:24    484 Cedar St, New York City, NY 10001      9
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 11            4    Los Angeles  (CA)  600.00    17      18      1
# 32            4  San Francisco  (CA)    5.98    17       0      1
# 33            4  San Francisco  (CA)  600.00    17       0      1
# 107           4         Boston  (MA)    3.84    17      10      1
# 138           4  New York City  (NY)   99.99    17      15      1
# ...         ...                  ...     ...   ...     ...    ...
# 186766        9         Dallas  (TX)  149.99    17      19      1
# 186825        9        Seattle  (WA)   14.95    17      21      1
# 186828        9         Boston  (MA)   11.95    17      34      1
# 186837        9  New York City  (NY)   99.99    17      24      1
# 186848        9  San Francisco  (CA)  379.99    17      30      1
#
# [10899 rows x 13 columns]), (18,        Order ID                     Product  Quantity Ordered  Price Each  \
# 17       176573        USB-C Charging Cable                 1       11.95
# 60       176613        USB-C Charging Cable                 2       11.95
# 66       176619               Flatscreen TV                 1      300.00
# ...
# 78            4  San Francisco  (CA)   11.95    18      48      1
# 89            4       Portland  (OR)    3.84    18      38      1
# ...         ...                  ...     ...   ...     ...    ...
# 186783        9         Boston  (MA)  700.00    18      54      1
# 186784        9         Boston  (MA)   14.95    18      54      1
# 186785        9         Boston  (MA)   14.95    18      54      1
# 186817        9        Seattle  (WA)  150.00    18      45      1
# 186823        9  San Francisco  (CA)   99.99    18       3      1
#
# [12280 rows x 13 columns]), (19,        Order ID                   Product  Quantity Ordered  Price Each  \
# 13       176569    27in 4K Gaming Monitor                 1      389.99
# 18       176574              Google Phone                 1      600.00
# 19       176574      USB-C Charging Cable                 1       11.95
# 22       176577  Apple Airpods Headphones                 1      150.00
# 34       176587          27in FHD Monitor                 1      149.99
# ...         ...                       ...               ...         ...
# 186801   259312          Wired Headphones                 1       11.99
# 186819   259329  Lightning Charging Cable                 1       14.95
# 186822   259332  Apple Airpods Headphones                 1      150.00
# 186834   259343      USB-C Charging Cable                 1       11.95
# 186843   259351  Apple Airpods Headphones                 1      150.00
#
#             Order Date                        Purchase Address  Month  \
# 13      04/16/19 19:23           657 Hill St, Dallas, TX 75001      4
# 18      04/03/19 19:42       20 Hill St, Los Angeles, CA 90001      4
# 19      04/03/19 19:42       20 Hill St, Los Angeles, CA 90001      4
# 22      04/04/19 19:25         260 Spruce St, Dallas, TX 75001      4
# 34      04/29/19 19:38       557 5th St, Los Angeles, CA 90001      4
# ...                ...                                     ...    ...
# 186801  09/02/19 19:51  573 Sunset St, San Francisco, CA 94016      9
# 186819  09/05/19 19:00       480 Lincoln St, Atlanta, GA 30301      9
# 186822  09/16/19 19:21          782 Lake St, Atlanta, GA 30301      9
# 186834  09/14/19 19:30          675 Maple St, Austin, TX 73301      9
# 186843  09/01/19 19:43     981 4th St, New York City, NY 10001      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 13            4         Dallas  (TX)  389.99    19      23      1
# 18            4    Los Angeles  (CA)  600.00    19      42      1
# 19            4    Los Angeles  (CA)   11.95    19      42      1
# 22            4         Dallas  (TX)  150.00    19      25      1
# 34            4    Los Angeles  (CA)  149.99    19      38      1
# ...         ...                  ...     ...   ...     ...    ...
# 186801        9  San Francisco  (CA)   11.99    19      51      1
# 186819        9        Atlanta  (GA)   14.95    19       0      1
# 186822        9        Atlanta  (GA)  150.00    19      21      1
# 186834        9         Austin  (TX)   11.95    19      30      1
# 186843        9  New York City  (NY)  150.00    19      43      1
#
# [12905 rows x 13 columns]), (20,        Order ID                   Product  Quantity Ordered  Price Each  \
# 16       176572  Apple Airpods Headphones                 1      150.00
# 29       176584             Flatscreen TV                 1      300.00
# 43       176596  Apple Airpods Headphones                 1      150.00
# 45       176598    AAA Batteries (4-pack)                 2        2.99
# 63       176616      USB-C Charging Cable                 1       11.95
# ...         ...                       ...               ...         ...
# 186792   259303     AA Batteries (4-pack)                 1        3.84
# 186794   259305     AA Batteries (4-pack)                 1        3.84
# 186831   259340     AA Batteries (4-pack)                 2        3.84
# 186833   259342     AA Batteries (4-pack)                 1        3.84
# 186845   259353    AAA Batteries (4-pack)                 3        2.99
#
#             Order Date                            Purchase Address  Month  \
# 16      04/04/19 20:30     149 Dogwood St, New York City, NY 10001      4
# 29      04/24/19 20:39      936 Church St, San Francisco, CA 94016      4
# 43      04/27/19 20:11             572 Meadow St, Dallas, TX 75001      4
# 45      04/21/19 20:33        294 Park St, San Francisco, CA 94016      4
# 63      04/05/19 20:40  380 Washington St, San Francisco, CA 94016      4
# ...                ...                                         ...    ...
# 186792  09/20/19 20:18               106 7th St, Atlanta, GA 30301      9
# 186794  09/24/19 20:46        47 North St, New York City, NY 10001      9
# 186831  09/18/19 20:18       544 Hickory St, Los Angeles, CA 90001      9
# 186833  09/07/19 20:09              579 South St, Boston, MA 02215      9
# 186845  09/17/19 20:56      840 Highland St, Los Angeles, CA 90001      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 16            4  New York City  (NY)  150.00    20      30      1
# 29            4  San Francisco  (CA)  300.00    20      39      1
# 43            4         Dallas  (TX)  150.00    20      11      1
# 45            4  San Francisco  (CA)    5.98    20      33      1
# 63            4  San Francisco  (CA)   11.95    20      40      1
# ...         ...                  ...     ...   ...     ...    ...
# 186792        9        Atlanta  (GA)    3.84    20      18      1
# 186794        9  New York City  (NY)    3.84    20      46      1
# 186831        9    Los Angeles  (CA)    7.68    20      18      1
# 186833        9         Boston  (MA)    3.84    20       9      1
# 186845        9    Los Angeles  (CA)    8.97    20      56      1
#
# [12228 rows x 13 columns]), (21,        Order ID                     Product  Quantity Ordered  Price Each  \
# 26       176581                      iPhone                 1      700.00
# 61       176614       AA Batteries (4-pack)                 1        3.84
# 65       176618    Lightning Charging Cable                 2       14.95
# 73       176626  Bose SoundSport Headphones                 1       99.99
# 88       176641    Lightning Charging Cable                 1       14.95
# ...         ...                         ...               ...         ...
# 186772   259287    Lightning Charging Cable                 1       14.95
# 186775   259290      AAA Batteries (4-pack)                 1        2.99
# 186807   259317    Lightning Charging Cable                 1       14.95
# 186829   259338      AAA Batteries (4-pack)                 2        2.99
# 186839   259348    Lightning Charging Cable                 1       14.95
#
#             Order Date                         Purchase Address  Month  \
# 26      04/09/19 21:38          84 Jackson St, Boston, MA 02215      4
# 61      04/07/19 21:01  647 Jackson St, San Francisco, CA 94016      4
# 65      04/18/19 21:44    273 South St, San Francisco, CA 94016      4
# 73      04/01/19 21:40        491 Chestnut St, Boston, MA 02215      4
# 88      04/25/19 21:36          655 Sunset St, Boston, MA 02215      4
# ...                ...                                      ...    ...
# 186772  09/09/19 21:24         675 Jackson St, Boston, MA 02215      9
# 186775  09/13/19 21:42             542 4th St, Dallas, TX 75001      9
# 186807  09/26/19 21:12      151 1st St, New York City, NY 10001      9
# 186829  09/02/19 21:29        666 Lakeview St, Boston, MA 02215      9
# 186839  09/30/19 21:03          260 Spruce St, Boston, MA 02215      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 26            4         Boston  (MA)  700.00    21      38      1
# 61            4  San Francisco  (CA)    3.84    21       1      1
# 65            4  San Francisco  (CA)   29.90    21      44      1
# 73            4         Boston  (MA)   99.99    21      40      1
# 88            4         Boston  (MA)   14.95    21      36      1
# ...         ...                  ...     ...   ...     ...    ...
# 186772        9         Boston  (MA)   14.95    21      24      1
# 186775        9         Dallas  (TX)    2.99    21      42      1
# 186807        9  New York City  (NY)   14.95    21      12      1
# 186829        9         Boston  (MA)    5.98    21      29      1
# 186839        9         Boston  (MA)   14.95    21       3      1
#
# [10921 rows x 13 columns]), (22,        Order ID                     Product  Quantity Ordered  Price Each  \
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 48       176601        USB-C Charging Cable                 1       11.95
# 87       176640            Wired Headphones                 2       11.99
# 126      176678       AA Batteries (4-pack)                 2        3.84
# 134      176685      34in Ultrawide Monitor                 1      379.99
# ...         ...                         ...               ...         ...
# 186767   259282        USB-C Charging Cable                 1       11.95
# 186788   259300            Wired Headphones                 1       11.99
# 186820   259330       AA Batteries (4-pack)                 2        3.84
# 186832   259341      27in 4K Gaming Monitor                 1      389.99
# 186840   259349      AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  Month  \
# 2       04/07/19 22:30       682 Chestnut St, Boston, MA 02215      4
# 48      04/02/19 22:32      754 10th St, Los Angeles, CA 90001      4
# 87      04/27/19 22:54    164 Lake St, San Francisco, CA 94016      4
# 126     04/19/19 22:12  345 Sunset St, San Francisco, CA 94016      4
# 134     04/23/19 22:53    114 10th St, New York City, NY 10001      4
# ...                ...                                     ...    ...
# 186767  09/01/19 22:54       806 9th St, Los Angeles, CA 90001      9
# 186788  09/17/19 22:07    932 13th St, San Francisco, CA 94016      9
# 186820  09/25/19 22:01    763 Washington St, Seattle, WA 98101      9
# 186832  09/24/19 22:16         501 Adams St, Seattle, WA 98101      9
# 186840  09/01/19 22:14          911 River St, Dallas, TX 75001      9
#
#         Month 2                 City   Sales  Hour  Minute  Count
# 2             4         Boston  (MA)   99.99    22      30      1
# 48            4    Los Angeles  (CA)   11.95    22      32      1
# 87            4  San Francisco  (CA)   23.98    22      54      1
# 126           4  San Francisco  (CA)    7.68    22      12      1
# 134           4  New York City  (NY)  379.99    22      53      1
# ...         ...                  ...     ...   ...     ...    ...
# 186767        9    Los Angeles  (CA)   11.95    22      54      1
# 186788        9  San Francisco  (CA)   11.99    22       7      1
# 186820        9        Seattle  (WA)    7.68    22       1      1
# 186832        9        Seattle  (WA)  389.99    22      16      1
# 186840        9         Dallas  (TX)    2.99    22      14      1
#
# [8822 rows x 13 columns]), (23,        Order ID                   Product  Quantity Ordered  Price Each  \
# 23       176578  Apple Airpods Headphones                 1      150.00
# 41       176594          Wired Headphones                 1       11.99
# 70       176623          27in FHD Monitor                 1      149.99
# 150      176700    34in Ultrawide Monitor                 1      379.99
# 158      176708          Wired Headphones                 1       11.99
# ...         ...                       ...               ...         ...
# 186787   259299        Macbook Pro Laptop                 1     1700.00
# 186816   259326    AAA Batteries (4-pack)                 3        2.99
# 186830   259339      USB-C Charging Cable                 2       11.95
# 186835   259344    AAA Batteries (4-pack)                 2        2.99
# 186836   259345           ThinkPad Laptop                 1      999.99
#
#             Order Date                         Purchase Address  Month  \
# 23      04/09/19 23:35          513 Church St, Boston, MA 02215      4
# 41      04/17/19 23:04     63 Maple St, San Francisco, CA 94016      4
# 70      04/20/19 23:51           807 12th St, Atlanta, GA 30301      4
# 150     04/07/19 23:10          967 Walnut St, Dallas, TX 75001      4
# 158     04/28/19 23:03    542 Ridge St, New York City, NY 10001      4
# ...                ...                                      ...    ...
# 186787  09/30/19 23:59   240 Chestnut St, Los Angeles, CA 90001      9
# 186816  09/15/19 23:01   163 Church St, New York City, NY 10001      9
# 186830  09/12/19 23:43            509 Park St, Austin, TX 73301      9
# 186835  09/10/19 23:33  721 Madison St, San Francisco, CA 94016      9
# 186836  09/21/19 23:12  406 Dogwood St, San Francisco, CA 94016      9
#
#         Month 2                 City    Sales  Hour  Minute  Count
# 23            4         Boston  (MA)   150.00    23      35      1
# 41            4  San Francisco  (CA)    11.99    23       4      1
# 70            4        Atlanta  (GA)   149.99    23      51      1
# 150           4         Dallas  (TX)   379.99    23      10      1
# 158           4  New York City  (NY)    11.99    23       3      1
# ...         ...                  ...      ...   ...     ...    ...
# 186787        9    Los Angeles  (CA)  1700.00    23      59      1
# 186816        9  New York City  (NY)     8.97    23       1      1
# 186830        9         Austin  (TX)    23.90    23      43      1
# 186835        9  San Francisco  (CA)     5.98    23      33      1
# 186836        9  San Francisco  (CA)   999.99    23      12      1
#
# [6275 rows x 13 columns])]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       1 keys = [pair for pair, df in all_data.groupby(['Hour'])]
#       2 keys = print([pair for pair in all_data.groupby(['Hour'])])
# ----> 4 plt.plot(keys, all_data.groupby(['Hour']).count()['Count'])
#       5 plt.xticks(keys)
#       6 plt.grid()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:459, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     456 # Don't allow any None value; these would be up-converted to one
#     457 # element array of None which causes problems downstream.
#     458 if any(v is None for v in tup):
# --> 459     raise ValueError("x, y, and format string must not be None")
#     461 kw = {}
#     462 for prop_name, val in zip(('linestyle', 'marker', 'color'),
#     463                           (linestyle, marker, color)):
#
# ValueError: x, y, and format string must not be None

# %% [markdown]
# #### Question 4: What products are most often sold together?

# %%
# https://stackoverflow.com/questions/43348194/pandas-select-rows-if-id-appear-several-time
df = all_data[all_data['Order ID'].duplicated(keep=False)]

# Referenced: https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()
# Out:
# C:\Users\13135\AppData\Local\Temp\ipykernel_5008\3772502071.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))
    print(count)

for key,value in count.most_common(10):
    print(key, value)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# #### What product sold the most? Why do you think it sold the most?

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
# Referenced: https://stackoverflow.com/questions/14762181/adding-a-y-axis-label-to-secondary-y-axis-in-matplotlib

prices = all_data.groupby('Product').mean()['Price Each']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color='g')
ax2.plot(keys, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(keys, rotation='vertical', size=8)

fig.show()
# Out:
# C:\Users\13135\AppData\Local\Temp\ipykernel_5008\136096346.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(keys, rotation='vertical', size=8)
# C:\Users\13135\AppData\Local\Temp\ipykernel_5008\136096346.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
